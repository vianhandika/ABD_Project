# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/ABD/Patient.csv')
data_general = pd.DataFrame()

data
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (20,21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                MSGTYPE  MSGCTRLID                             PATIENTID  \
# 0      ADT^A31^ADT_A31    1122037  00078573-afe8-4090-9c69-cca5c9cd810b
# 1      ADT^A02^ADT_A02    1112342  000da23a-7b41-4a03-a3f2-ff49ea379c59
# 2      ADT^A31^ADT_A31    1121751  000f1b5b-95ac-493c-b22f-7df769821ba6
# 3      ADT^A38^ADT_A38    1126302  000f4bea-757a-440d-a09d-efce7e34541f
# 4      ADT^A05^ADT_A05    1117001  0017fcbd-2953-4cd1-8afb-f4e0ccec657d
# ...                ...        ...                                   ...
# 68770  ADT^A05^ADT_A05    3036442  a926543e-b697-43eb-b084-717bada52cfc
# 68771  ADT^A31^ADT_A31    3036443  ab5f55b2-48de-4d54-8c7c-4ef2d1cb2701
# 68772  ADT^A31^ADT_A31    3036444  ab5f55b2-48de-4d54-8c7c-4ef2d1cb2701
# ...

# %%
data_general['PATIENTID'] = data['PATIENTID']
data_general['SSN'] = data['SSN']

data_general['NAME'] = data[["FIRST", "LAST"]].apply(" ".join, axis=1)
data_general['GENDER'] = data['GENDER']
data_general['BIRTHDATE'] = data['BIRTHDATE']
data_general['DEATHDATE'] = data['DEATHDATE']
data_general['BIRTHPLACE'] = data['BIRTHPLACE']
data_general['ADDRESS'] = data['ADDRESS']



data_general.to_csv(r'/content/drive/MyDrive/ABD/Data_General.csv', index = False, header = True,index_label=None)
data_general
# Out:
#                                   PATIENTID                      NAME GENDER  \
# 0      00078573-afe8-4090-9c69-cca5c9cd810b         Dixie181 Welch248      F
# 1      000da23a-7b41-4a03-a3f2-ff49ea379c59      Chin491 Bergstrom451      F
# 2      000f1b5b-95ac-493c-b22f-7df769821ba6        Elbert922 Walsh907      M
# 3      000f4bea-757a-440d-a09d-efce7e34541f          Gale768 Sauer905      M
# 4      0017fcbd-2953-4cd1-8afb-f4e0ccec657d      Star826 Halvorson947      F
# ...                                     ...                       ...    ...
# 68770  a926543e-b697-43eb-b084-717bada52cfc            Alva10 Bruen68      M
# 68771  ab5f55b2-48de-4d54-8c7c-4ef2d1cb2701  Carlita892 Jakubowski550      F
# 68772  ab5f55b2-48de-4d54-8c7c-4ef2d1cb2701  Carlita892 Jakubowski550      F
# 68773  c82956a6-6db8-47ac-b5d3-69289752a26d      Randy581 Bogisich591      M
# 68774  c82956a6-6db8-47ac-b5d3-69289752a26d         Burton823 Nolan84      M
#
# ...
