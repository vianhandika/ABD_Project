# %% [markdown]
# Implementasi Python Spark untuk klasifikasi gejala yang di alami oleh pasien pada FHIR dataset berdasarkan observasi yang dihasilkan. Ada 4 label klasifikasi,  yaitu: ambulatory, wellness, outpatient, dan wellness.

# %% [markdown]
# Ada beberapa step yang dilakukan yaitu:
#
#
#
# 1.   **Install Spark pada Google Colab**
# 2.   **Data preparation**
# 3.   **Decision Tree**
# 4.   **Evaluation**

# %% [markdown]
# # Step 1: Installing Spark on Google Colab

# %%
# Checking folder
# !ls
# Out:
# sample_data

# %%
# Installing JDK
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Getting Spark installer (check the path on spark.apache.org)
# !wget -q https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop2.7.tgz

# %%
# Checking if the file is copied
# !ls
# Out:
# sample_data  spark-3.2.1-bin-hadoop2.7.tgz

# %%
# Untar the Spark installer
# !tar -xvf spark-3.2.1-bin-hadoop2.7.tgz
# Out:
# spark-3.2.1-bin-hadoop2.7/
# spark-3.2.1-bin-hadoop2.7/LICENSE
# spark-3.2.1-bin-hadoop2.7/NOTICE
# spark-3.2.1-bin-hadoop2.7/R/
# spark-3.2.1-bin-hadoop2.7/R/lib/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/DESCRIPTION
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/INDEX
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/Rd.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/features.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/hsearch.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/links.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/Meta/package.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/NAMESPACE
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/R/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/R/SparkR
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/R/SparkR.rdb
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/R/SparkR.rdx
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/AnIndex
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/SparkR.rdb
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/SparkR.rdx
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/aliases.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/help/paths.rds
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/html/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/html/00Index.html
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/html/R.css
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/profile/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/profile/general.R
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/profile/shell.R
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/tests/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/tests/testthat/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/tests/testthat/test_basic.R
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/worker/
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/worker/daemon.R
# spark-3.2.1-bin-hadoop2.7/R/lib/SparkR/worker/worker.R
# spark-3.2.1-bin-hadoop2.7/R/lib/sparkr.zip
# spark-3.2.1-bin-hadoop2.7/README.md
# spark-3.2.1-bin-hadoop2.7/RELEASE
# spark-3.2.1-bin-hadoop2.7/bin/
# spark-3.2.1-bin-hadoop2.7/bin/beeline
# spark-3.2.1-bin-hadoop2.7/bin/beeline.cmd
# spark-3.2.1-bin-hadoop2.7/bin/docker-image-tool.sh
# spark-3.2.1-bin-hadoop2.7/bin/find-spark-home
# spark-3.2.1-bin-hadoop2.7/bin/find-spark-home.cmd
# spark-3.2.1-bin-hadoop2.7/bin/load-spark-env.cmd
# spark-3.2.1-bin-hadoop2.7/bin/load-spark-env.sh
# spark-3.2.1-bin-hadoop2.7/bin/pyspark
# spark-3.2.1-bin-hadoop2.7/bin/pyspark.cmd
# spark-3.2.1-bin-hadoop2.7/bin/pyspark2.cmd
# spark-3.2.1-bin-hadoop2.7/bin/run-example
# spark-3.2.1-bin-hadoop2.7/bin/run-example.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-class
# spark-3.2.1-bin-hadoop2.7/bin/spark-class.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-class2.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-shell
# spark-3.2.1-bin-hadoop2.7/bin/spark-shell.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-shell2.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-sql
# spark-3.2.1-bin-hadoop2.7/bin/spark-sql.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-sql2.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-submit
# spark-3.2.1-bin-hadoop2.7/bin/spark-submit.cmd
# spark-3.2.1-bin-hadoop2.7/bin/spark-submit2.cmd
# spark-3.2.1-bin-hadoop2.7/bin/sparkR
# spark-3.2.1-bin-hadoop2.7/bin/sparkR.cmd
# spark-3.2.1-bin-hadoop2.7/bin/sparkR2.cmd
# spark-3.2.1-bin-hadoop2.7/conf/
# spark-3.2.1-bin-hadoop2.7/conf/fairscheduler.xml.template
# spark-3.2.1-bin-hadoop2.7/conf/log4j.properties.template
# spark-3.2.1-bin-hadoop2.7/conf/metrics.properties.template
# spark-3.2.1-bin-hadoop2.7/conf/spark-defaults.conf.template
# spark-3.2.1-bin-hadoop2.7/conf/spark-env.sh.template
# spark-3.2.1-bin-hadoop2.7/conf/workers.template
# spark-3.2.1-bin-hadoop2.7/data/
# spark-3.2.1-bin-hadoop2.7/data/graphx/
# spark-3.2.1-bin-hadoop2.7/data/graphx/followers.txt
# spark-3.2.1-bin-hadoop2.7/data/graphx/users.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/
# spark-3.2.1-bin-hadoop2.7/data/mllib/als/
# spark-3.2.1-bin-hadoop2.7/data/mllib/als/sample_movielens_ratings.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/als/test.data
# spark-3.2.1-bin-hadoop2.7/data/mllib/gmm_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/license.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/29.5.a_b_EGDP022204.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/54893.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/DP153539.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/DP802813.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/kittens/not-image.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/license.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/multi-channel/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/multi-channel/BGRA.png
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/multi-channel/BGRA_alpha_60.png
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/multi-channel/chr30.4.184.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/origin/multi-channel/grayscale.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-01/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-01/29.5.a_b_EGDP022204.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-01/not-image.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-02/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-02/54893.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-02/DP153539.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=kittens/date=2018-02/DP802813.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-01/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-01/BGRA.png
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-01/BGRA_alpha_60.png
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-02/
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-02/chr30.4.184.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/images/partitioned/cls=multichannel/date=2018-02/grayscale.jpg
# spark-3.2.1-bin-hadoop2.7/data/mllib/iris_libsvm.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/kmeans_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/pagerank_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/pic_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/ridge-data/
# spark-3.2.1-bin-hadoop2.7/data/mllib/ridge-data/lpsa.data
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_binary_classification_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_fpgrowth.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_isotonic_regression_libsvm_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_kmeans_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_lda_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_lda_libsvm_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_libsvm_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_linear_regression_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_movielens_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_multiclass_classification_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/sample_svm_data.txt
# spark-3.2.1-bin-hadoop2.7/data/mllib/streaming_kmeans_data_test.txt
# spark-3.2.1-bin-hadoop2.7/data/streaming/
# spark-3.2.1-bin-hadoop2.7/data/streaming/AFINN-111.txt
# spark-3.2.1-bin-hadoop2.7/examples/
# spark-3.2.1-bin-hadoop2.7/examples/jars/
# spark-3.2.1-bin-hadoop2.7/examples/jars/scopt_2.12-3.7.1.jar
# spark-3.2.1-bin-hadoop2.7/examples/jars/spark-examples_2.12-3.2.1.jar
# spark-3.2.1-bin-hadoop2.7/examples/src/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaHdfsLR.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaLogQuery.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaPageRank.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaSparkPi.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaStatusTrackerDemo.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaTC.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/JavaWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaAFTSurvivalRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaALSExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaBinarizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaBisectingKMeansExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketedRandomProjectionLSHExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSqSelectorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSquareTestExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaCorrelationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaCountVectorizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaDCTExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeClassificationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaDocument.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaElementwiseProductExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaEstimatorTransformerParamExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaFMClassifierExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaFMRegressorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaFPGrowthExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaFeatureHasherExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaGaussianMixtureExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaGeneralizedLinearRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeClassifierExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeRegressorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaImputerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaIndexToStringExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaInteractionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaIsotonicRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaKMeansExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLDAExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLabeledDocument.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearRegressionWithElasticNetExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearSVCExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionSummaryExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionWithElasticNetExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaMaxAbsScalerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaMinHashLSHExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaMinMaxScalerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaCrossValidationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaTrainValidationSplitExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaMulticlassLogisticRegressionWithElasticNetExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaMultilayerPerceptronClassifierExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaNGramExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaNaiveBayesExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaNormalizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaOneHotEncoderExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaOneVsRestExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaPCAExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaPipelineExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaPolynomialExpansionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaPowerIterationClusteringExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaPrefixSpanExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaQuantileDiscretizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaRFormulaExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestClassifierExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestRegressorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaRobustScalerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaSQLTransformerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaStandardScalerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaStopWordsRemoverExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaStringIndexerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaSummarizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaTfIdfExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaTokenizerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaUnivariateFeatureSelectorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaVarianceThresholdSelectorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorAssemblerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorIndexerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSizeHintExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSlicerExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/ml/JavaWord2VecExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaALS.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaAssociationRulesExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaBinaryClassificationMetricsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaBisectingKMeansExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaChiSqSelectorExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaCorrelationsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeClassificationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaElementwiseProductExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaGaussianMixtureExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingClassificationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingKolmogorovSmirnovTestExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaIsotonicRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaKMeansExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaKernelDensityEstimationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaLBFGSExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaLatentDirichletAllocationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaLogisticRegressionWithLBFGSExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaMultiLabelClassificationMetricsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaMulticlassClassificationMetricsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaNaiveBayesExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaPCAExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaPowerIterationClusteringExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaPrefixSpanExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestClassificationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestRegressionExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaRankingMetricsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaRecommendationExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVDExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVMWithSGDExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaSimpleFPGrowth.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaStratifiedSamplingExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaStreamingTestExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/mllib/JavaSummaryStatisticsExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/JavaSQLDataSourceExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/JavaSparkSQLExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedScalar.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedTypedAggregation.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedUntypedAggregation.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/hive/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/hive/JavaSparkHiveExample.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredComplexSessionization.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKafkaWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKerberizedKafkaWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCountWindowed.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredSessionization.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaCustomReceiver.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKafkaWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKerberizedKafkaWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaNetworkWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaQueueStream.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecord.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecoverableNetworkWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaSqlNetworkWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/java/org/apache/spark/examples/streaming/JavaStatefulNetworkWordCount.java
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/als.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/avro_inputformat.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/kmeans.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/logistic_regression.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/aft_survival_regression.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/als_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/binarizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/bisecting_k_means_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/bucketed_random_projection_lsh_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/bucketizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/chi_square_test_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/chisq_selector_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/correlation_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/count_vectorizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/cross_validator.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/dataframe_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/dct_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/decision_tree_classification_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/decision_tree_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/elementwise_product_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/estimator_transformer_param_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/feature_hasher_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/fm_classifier_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/fm_regressor_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/fpgrowth_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/gaussian_mixture_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/generalized_linear_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/gradient_boosted_tree_classifier_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/gradient_boosted_tree_regressor_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/imputer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/index_to_string_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/interaction_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/isotonic_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/kmeans_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/lda_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/linear_regression_with_elastic_net.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/linearsvc.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/logistic_regression_summary_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/logistic_regression_with_elastic_net.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/max_abs_scaler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/min_hash_lsh_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/min_max_scaler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/multiclass_logistic_regression_with_elastic_net.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/multilayer_perceptron_classification.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/n_gram_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/naive_bayes_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/normalizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/one_vs_rest_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/onehot_encoder_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/pca_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/pipeline_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/polynomial_expansion_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/power_iteration_clustering_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/prefixspan_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/quantile_discretizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/random_forest_classifier_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/random_forest_regressor_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/rformula_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/robust_scaler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/sql_transformer.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/standard_scaler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/stopwords_remover_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/string_indexer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/summarizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/tf_idf_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/tokenizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/train_validation_split.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/univariate_feature_selector_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/variance_threshold_selector_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/vector_assembler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/vector_indexer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/vector_size_hint_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/vector_slicer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/ml/word2vec_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/binary_classification_metrics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/bisecting_k_means_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/correlations.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/correlations_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/decision_tree_classification_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/decision_tree_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/elementwise_product_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/fpgrowth_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/gaussian_mixture_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/gaussian_mixture_model.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/gradient_boosting_classification_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/gradient_boosting_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/hypothesis_testing_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/hypothesis_testing_kolmogorov_smirnov_test_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/isotonic_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/k_means_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/kernel_density_estimation_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/kmeans.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/latent_dirichlet_allocation_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/linear_regression_with_sgd_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/logistic_regression.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/logistic_regression_with_lbfgs_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/multi_class_metrics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/multi_label_metrics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/naive_bayes_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/normalizer_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/pca_rowmatrix_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/power_iteration_clustering_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/random_forest_classification_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/random_forest_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/random_rdd_generation.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/ranking_metrics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/recommendation_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/regression_metrics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/sampled_rdds.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/standard_scaler_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/stratified_sampling_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/streaming_k_means_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/streaming_linear_regression_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/summary_statistics_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/svd_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/svm_with_sgd_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/tf_idf_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/word2vec.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/mllib/word2vec_example.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/pagerank.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/parquet_inputformat.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/pi.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sort.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/arrow.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/basic.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/datasource.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/hive.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/streaming/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/streaming/structured_kafka_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/streaming/structured_network_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/streaming/structured_network_wordcount_windowed.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/sql/streaming/structured_sessionization.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/status_api_demo.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/hdfs_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/network_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/network_wordjoinsentiments.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/queue_stream.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/recoverable_network_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/sql_network_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/streaming/stateful_network_wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/transitive_closure.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/python/wordcount.py
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/RSparkSQLExample.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/data-manipulation.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/dataframe.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/als.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/bisectingKmeans.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/decisionTree.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/fmClassifier.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/fmRegressor.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/fpm.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/gaussianMixture.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/gbt.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/glm.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/isoreg.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/kmeans.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/kstest.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/lda.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/lm_with_elastic_net.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/logit.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/ml.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/mlp.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/naiveBayes.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/powerIterationClustering.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/prefixSpan.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/randomForest.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/survreg.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/ml/svmLinear.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/streaming/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/r/streaming/structured_network_wordcount.R
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/META-INF/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/META-INF/services/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/META-INF/services/org.apache.spark.sql.SparkSessionExtensionsProvider
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/META-INF/services/org.apache.spark.sql.jdbc.JdbcConnectionProvider
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/dir1/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/dir1/dir2/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/dir1/dir2/file2.parquet
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/dir1/file1.parquet
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/dir1/file3.json
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/employees.json
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/full_user.avsc
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/kv1.txt
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/people.csv
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/people.json
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/people.txt
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/user.avsc
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/users.avro
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/users.orc
# spark-3.2.1-bin-hadoop2.7/examples/src/main/resources/users.parquet
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/AccumulatorMetricsTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/BroadcastTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/DFSReadWriteTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/DriverSubmissionTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ExceptionHandlingTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/GroupByTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/HdfsTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LocalALS.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LocalFileLR.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LocalKMeans.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LocalLR.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LocalPi.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/LogQuery.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/MultiBroadcastTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SimpleSkewedGroupByTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SkewedGroupByTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkALS.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkHdfsLR.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkKMeans.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkLR.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkPageRank.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkPi.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkRemoteFileTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/SparkTC.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/extensions/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/extensions/AgeExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/extensions/SessionExtensionsWithLoader.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/extensions/SessionExtensionsWithoutLoader.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/extensions/SparkSessionExtensionsTest.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/AggregateMessagesExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/Analytics.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/ComprehensiveExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/ConnectedComponentsExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/LiveJournalPageRank.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/PageRankExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/SSSPExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/SynthBenchmark.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/graphx/TriangleCountingExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/AFTSurvivalRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ALSExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/BinarizerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/BisectingKMeansExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/BucketedRandomProjectionLSHExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/BucketizerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ChiSqSelectorExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ChiSquareTestExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/CorrelationExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/CountVectorizerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DCTExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DataFrameExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeClassificationExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DecisionTreeRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/DeveloperApiExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ElementwiseProductExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/EstimatorTransformerParamExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/FMClassifierExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/FMRegressorExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/FPGrowthExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/FeatureHasherExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/GBTExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/GaussianMixtureExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/GeneralizedLinearRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeClassifierExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/GradientBoostedTreeRegressorExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ImputerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/IndexToStringExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/InteractionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/IsotonicRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/KMeansExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LDAExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LinearRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LinearRegressionWithElasticNetExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LinearSVCExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionSummaryExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/LogisticRegressionWithElasticNetExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/MaxAbsScalerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/MinHashLSHExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/MinMaxScalerExample.scala
# spark-3.2.1-bin-hadoop2.7/examples/src/main/scala/org/apache/spark/examples/ml/ModelSelectionViaCrossValidationExample.scala
# ...
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/information.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/information.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/profile.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/profile.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/requests.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/requests.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/tests/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/tests/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resource/tests/test_resources.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resultiterable.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/resultiterable.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/serializers.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/shell.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/shuffle.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/__init__.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/_typing.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/avro/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/avro/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/avro/functions.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/avro/functions.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/catalog.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/catalog.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/column.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/column.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/conf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/conf.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/context.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/context.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/dataframe.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/dataframe.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/functions.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/functions.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/group.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/group.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/__init__.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/protocols/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/protocols/__init__.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/protocols/frame.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/_typing/protocols/series.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/conversion.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/conversion.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/functions.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/functions.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/group_ops.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/group_ops.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/map_ops.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/map_ops.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/serializers.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/typehints.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/types.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/pandas/utils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/readwriter.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/readwriter.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/session.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/session.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/streaming.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/streaming.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_arrow.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_catalog.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_column.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_conf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_context.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_dataframe.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_datasources.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_functions.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_group.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_cogrouped_map.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_grouped_map.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_map.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_udf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_udf_grouped_agg.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_udf_scalar.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_udf_typehints.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_pandas_udf_window.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_readwriter.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_serde.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_session.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_streaming.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_types.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_udf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/tests/test_utils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/types.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/types.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/udf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/udf.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/utils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/window.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/window.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/statcounter.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/statcounter.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/status.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/status.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/storagelevel.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/storagelevel.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/context.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/context.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/dstream.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/dstream.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/kinesis.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/kinesis.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/listener.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/listener.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/test_context.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/test_dstream.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/test_kinesis.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/tests/test_listener.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/streaming/util.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/taskcontext.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/taskcontext.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/mllibutils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/mlutils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/pandasutils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/sqlutils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/streamingutils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/testing/utils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/__init__.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_appsubmit.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_broadcast.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_conf.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_context.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_daemon.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_install_spark.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_join.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_pin_thread.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_profiler.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_rdd.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_rddbarrier.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_readwrite.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_serializers.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_shuffle.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_taskcontext.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_util.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/tests/test_worker.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/traceback_utils.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/util.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/util.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/version.py
# spark-3.2.1-bin-hadoop2.7/python/pyspark/version.pyi
# spark-3.2.1-bin-hadoop2.7/python/pyspark/worker.py
# spark-3.2.1-bin-hadoop2.7/python/run-tests
# spark-3.2.1-bin-hadoop2.7/python/run-tests-with-coverage
# spark-3.2.1-bin-hadoop2.7/python/run-tests.py
# spark-3.2.1-bin-hadoop2.7/python/setup.cfg
# spark-3.2.1-bin-hadoop2.7/python/setup.py
# spark-3.2.1-bin-hadoop2.7/python/test_coverage/
# spark-3.2.1-bin-hadoop2.7/python/test_coverage/conf/
# spark-3.2.1-bin-hadoop2.7/python/test_coverage/conf/spark-defaults.conf
# spark-3.2.1-bin-hadoop2.7/python/test_coverage/coverage_daemon.py
# spark-3.2.1-bin-hadoop2.7/python/test_coverage/sitecustomize.py
# spark-3.2.1-bin-hadoop2.7/python/test_support/
# spark-3.2.1-bin-hadoop2.7/python/test_support/SimpleHTTPServer.py
# spark-3.2.1-bin-hadoop2.7/python/test_support/hello/
# spark-3.2.1-bin-hadoop2.7/python/test_support/hello/hello.txt
# spark-3.2.1-bin-hadoop2.7/python/test_support/hello/sub_hello/
# spark-3.2.1-bin-hadoop2.7/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/ages.csv
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/ages_newlines.csv
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=0/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=1/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/_SUCCESS
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/_common_metadata
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/_metadata
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2014/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2014/month=9/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/.part-r-00008.gz.parquet.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/part-r-00008.gz.parquet
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00002.gz.parquet.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00004.gz.parquet.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00002.gz.parquet
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00004.gz.parquet
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/.part-r-00005.gz.parquet.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/part-r-00005.gz.parquet
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=9/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/.part-r-00007.gz.parquet.crc
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/part-r-00007.gz.parquet
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/people.json
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/people1.json
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/people_array.json
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/people_array_utf16le.json
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/streaming/
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/streaming/text-test.txt
# spark-3.2.1-bin-hadoop2.7/python/test_support/sql/text-test.txt
# spark-3.2.1-bin-hadoop2.7/python/test_support/userlib-0.1.zip
# spark-3.2.1-bin-hadoop2.7/python/test_support/userlibrary.py
# spark-3.2.1-bin-hadoop2.7/sbin/
# spark-3.2.1-bin-hadoop2.7/sbin/decommission-slave.sh
# spark-3.2.1-bin-hadoop2.7/sbin/decommission-worker.sh
# spark-3.2.1-bin-hadoop2.7/sbin/slaves.sh
# spark-3.2.1-bin-hadoop2.7/sbin/spark-config.sh
# spark-3.2.1-bin-hadoop2.7/sbin/spark-daemon.sh
# spark-3.2.1-bin-hadoop2.7/sbin/spark-daemons.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-all.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-history-server.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-master.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-mesos-dispatcher.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-mesos-shuffle-service.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-slave.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-slaves.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-thriftserver.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-worker.sh
# spark-3.2.1-bin-hadoop2.7/sbin/start-workers.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-all.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-history-server.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-master.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-mesos-dispatcher.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-mesos-shuffle-service.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-slave.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-slaves.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-thriftserver.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-worker.sh
# spark-3.2.1-bin-hadoop2.7/sbin/stop-workers.sh
# spark-3.2.1-bin-hadoop2.7/sbin/workers.sh
# spark-3.2.1-bin-hadoop2.7/yarn/
# spark-3.2.1-bin-hadoop2.7/yarn/spark-3.2.1-yarn-shuffle.jar

# %%
# Checking the Spark folder after untar
# !ls
# Out:
# sample_data  spark-3.2.1-bin-hadoop2.7	spark-3.2.1-bin-hadoop2.7.tgz

# %%
# Installing findspark - a python library to find Spark
# !pip install -q findspark

# %%
# Setting environment variables: Setting Java and Spark home based on the location where they are stored
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop2.7"

# %%
# Creating a local Spark session
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %% [markdown]
# # Step 2: Data Preparation

# %%
# Loading data observations in pandas dataframe
import pandas as pd
observation_df = pd.read_csv("https://raw.githubusercontent.com/laksmitawidya/fhir-project/master/observations.csv") 
observation_df.head()
# Out:
#                    DATE                               PATIENT  \
# 0  2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 1  2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 2  2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 3  2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 4  2012-01-23T17:45:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
#
#                               ENCOUNTER     CODE  \
# 0  e88bc3a9-007c-405e-aabc-792a38f4aa2b   8302-2
# 1  e88bc3a9-007c-405e-aabc-792a38f4aa2b  72514-3
# 2  e88bc3a9-007c-405e-aabc-792a38f4aa2b  29463-7
# 3  e88bc3a9-007c-405e-aabc-792a38f4aa2b  39156-5
# 4  e88bc3a9-007c-405e-aabc-792a38f4aa2b   8462-4
#
#                                          DESCRIPTION  VALUE    UNITS     TYPE
# 0                                        Body Height  193.3       cm  numeric
# 1  Pain severity - 0-10 verbal numeric rating [Sc...    2.0  {score}  numeric
# 2                                        Body Weight   87.8       kg  numeric
# 3                                    Body Mass Index   23.5    kg/m2  numeric
# 4                           Diastolic Blood Pressure   82.0   mm[Hg]  numeric

# %%
# Loading data encounter in pandas dataframe
import pandas as pd
encounter_df = pd.read_csv("https://raw.githubusercontent.com/laksmitawidya/fhir-project/master/encounters.csv") 
encounter_df.head()
# Out:
#                                      Id                 START  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5  2010-01-23T17:45:28Z
# 1  e88bc3a9-007c-405e-aabc-792a38f4aa2b  2012-01-23T17:45:28Z
# 2  8f104aa7-4ca9-4473-885a-bba2437df588  2001-05-01T15:02:18Z
# 3  b85c339a-6076-43ed-b9d0-9cf013dec49d  2011-07-28T15:02:18Z
# 4  dae2b7cb-1316-4b78-954f-fa610a6c6d0e  2010-07-27T12:58:08Z
#
#                    STOP                               PATIENT  \
# 0  2010-01-23T18:10:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 1  2012-01-23T18:00:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 2  2001-05-01T15:17:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 3  2011-07-28T15:17:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 4  2010-07-27T13:28:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
#
#                            ORGANIZATION                              PROVIDER  \
# 0  e002090d-4e92-300e-b41e-7d1f21dee4c6  e6283e46-fd81-3611-9459-0edb1c3da357
# 1  772ee193-bb9f-30eb-9939-21e86c8e4da5  6f1d59a7-a5bd-3cf9-9671-5bad2f351c28
# 2  5d4b9df1-93ae-3bc9-b680-03249990e558  af01a385-31d3-3c77-8fdb-2867fe88df2f
# 3  3dc9bb2d-5d66-3e61-bf9a-e234c6433577  bb17e691-262b-3546-93d5-d88e7de93246
# 4  b03dba4f-892f-365c-bfd1-bfcfa7a98d5d  7ed6b84a-b847-3744-9d42-15c42297a0c2
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  6e2f1a2d-27bd-3701-8d08-dae202c58632     ambulatory  185345009
# 1  6e2f1a2d-27bd-3701-8d08-dae202c58632       wellness  162673000
# 2  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     ambulatory  185345009
# 3  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76       wellness  162673000
# 4  d47b3510-2895-3b70-9897-342d681c769d       wellness  162673000
#
#                                   DESCRIPTION  BASE_ENCOUNTER_COST  \
# 0                       Encounter for symptom               129.16
# 1  General examination of patient (procedure)               129.16
# 2                       Encounter for symptom               129.16
# 3  General examination of patient (procedure)               129.16
# 4  General examination of patient (procedure)               129.16
#
#    TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE            REASONDESCRIPTION
# 0            129.16           54.16  10509002.0  Acute bronchitis (disorder)
# 1            129.16          129.16         NaN                          NaN
# 2            129.16            0.00  36971009.0         Sinusitis (disorder)
# 3            129.16            0.00         NaN                          NaN
# 4            129.16          129.16         NaN                          NaN

# %%
# Dropping all null rows & change NaN to 0
observation_df.dropna(how="all", inplace=True)
observation_df.fillna(0)
observation_df.shape

encounter_df.dropna(how="all", inplace=True)
encounter_df.fillna(0)
encounter_df.shape
# Out:
# (53346, 15)

# %%
# Replacing carriage return and new line characters with a space
observation_df = observation_df.replace({r'\r\n': ' '}, regex=True)
observation_df.head()

encounter_df = encounter_df.replace({r'\r\n': ' '}, regex=True)
encounter_df.head()
# Out:
#                                      Id                 START  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5  2010-01-23T17:45:28Z
# 1  e88bc3a9-007c-405e-aabc-792a38f4aa2b  2012-01-23T17:45:28Z
# 2  8f104aa7-4ca9-4473-885a-bba2437df588  2001-05-01T15:02:18Z
# 3  b85c339a-6076-43ed-b9d0-9cf013dec49d  2011-07-28T15:02:18Z
# 4  dae2b7cb-1316-4b78-954f-fa610a6c6d0e  2010-07-27T12:58:08Z
#
#                    STOP                               PATIENT  \
# 0  2010-01-23T18:10:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 1  2012-01-23T18:00:28Z  034e9e3b-2def-4559-bb2a-7850888ae060
# 2  2001-05-01T15:17:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 3  2011-07-28T15:17:18Z  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 4  2010-07-27T13:28:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
#
#                            ORGANIZATION                              PROVIDER  \
# 0  e002090d-4e92-300e-b41e-7d1f21dee4c6  e6283e46-fd81-3611-9459-0edb1c3da357
# 1  772ee193-bb9f-30eb-9939-21e86c8e4da5  6f1d59a7-a5bd-3cf9-9671-5bad2f351c28
# 2  5d4b9df1-93ae-3bc9-b680-03249990e558  af01a385-31d3-3c77-8fdb-2867fe88df2f
# 3  3dc9bb2d-5d66-3e61-bf9a-e234c6433577  bb17e691-262b-3546-93d5-d88e7de93246
# 4  b03dba4f-892f-365c-bfd1-bfcfa7a98d5d  7ed6b84a-b847-3744-9d42-15c42297a0c2
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  6e2f1a2d-27bd-3701-8d08-dae202c58632     ambulatory  185345009
# 1  6e2f1a2d-27bd-3701-8d08-dae202c58632       wellness  162673000
# 2  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76     ambulatory  185345009
# 3  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76       wellness  162673000
# 4  d47b3510-2895-3b70-9897-342d681c769d       wellness  162673000
#
#                                   DESCRIPTION  BASE_ENCOUNTER_COST  \
# 0                       Encounter for symptom               129.16
# 1  General examination of patient (procedure)               129.16
# 2                       Encounter for symptom               129.16
# 3  General examination of patient (procedure)               129.16
# 4  General examination of patient (procedure)               129.16
#
#    TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE            REASONDESCRIPTION
# 0            129.16           54.16  10509002.0  Acute bronchitis (disorder)
# 1            129.16          129.16         NaN                          NaN
# 2            129.16            0.00  36971009.0         Sinusitis (disorder)
# 3            129.16            0.00         NaN                          NaN
# 4            129.16          129.16         NaN                          NaN

# %% [markdown]
# ## Create PySpark DataFrame

# %%
# Converting Pandas Dataframe into Spark Dataframe
encounter_df = encounter_df.astype(str) # Converting pandas df to string first
encounter_df.dtypes
encounter_sdf = spark.createDataFrame(encounter_df)
encounter_sdf.show(10, False) # False allows us to show entire content of the columns
# Out:
# +------------------------------------+--------------------+--------------------+------------------------------------+------------------------------------+------------------------------------+------------------------------------+--------------+---------+------------------------------------------+-------------------+----------------+--------------+-----------+----------------------------------+
# |Id                                  |START               |STOP                |PATIENT                             |ORGANIZATION                        |PROVIDER                            |PAYER                               |ENCOUNTERCLASS|CODE     |DESCRIPTION                               |BASE_ENCOUNTER_COST|TOTAL_CLAIM_COST|PAYER_COVERAGE|REASONCODE |REASONDESCRIPTION                 |
# +------------------------------------+--------------------+--------------------+------------------------------------+------------------------------------+------------------------------------+------------------------------------+--------------+---------+------------------------------------------+-------------------+----------------+--------------+-----------+----------------------------------+
# |d0c40d10-8d87-447e-836e-99d26ad52ea5|2010-01-23T17:45:28Z|2010-01-23T18:10:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e002090d-4e92-300e-b41e-7d1f21dee4c6|e6283e46-fd81-3611-9459-0edb1c3da357|6e2f1a2d-27bd-3701-8d08-dae202c58632|ambulatory    |185345009|Encounter for symptom                     |129.16             |129.16          |54.16         |10509002.0 |Acute bronchitis (disorder)       |
# |e88bc3a9-007c-405e-aabc-792a38f4aa2b|2012-01-23T17:45:28Z|2012-01-23T18:00:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|772ee193-bb9f-30eb-9939-21e86c8e4da5|6f1d59a7-a5bd-3cf9-9671-5bad2f351c28|6e2f1a2d-27bd-3701-8d08-dae202c58632|wellness      |162673000|General examination of patient (procedure)|129.16             |129.16          |129.16        |nan        |nan                               |
# |8f104aa7-4ca9-4473-885a-bba2437df588|2001-05-01T15:02:18Z|2001-05-01T15:17:18Z|1d604da9-9a81-4ba9-80c2-de3375d59b40|5d4b9df1-93ae-3bc9-b680-03249990e558|af01a385-31d3-3c77-8fdb-2867fe88df2f|b1c428d6-4f07-31e0-90f0-68ffa6ff8c76|ambulatory    |185345009|Encounter for symptom                     |129.16             |129.16          |0.0           |36971009.0 |Sinusitis (disorder)              |
# |b85c339a-6076-43ed-b9d0-9cf013dec49d|2011-07-28T15:02:18Z|2011-07-28T15:17:18Z|1d604da9-9a81-4ba9-80c2-de3375d59b40|3dc9bb2d-5d66-3e61-bf9a-e234c6433577|bb17e691-262b-3546-93d5-d88e7de93246|b1c428d6-4f07-31e0-90f0-68ffa6ff8c76|wellness      |162673000|General examination of patient (procedure)|129.16             |129.16          |0.0           |nan        |nan                               |
# |dae2b7cb-1316-4b78-954f-fa610a6c6d0e|2010-07-27T12:58:08Z|2010-07-27T13:28:08Z|10339b10-3cd1-4ac3-ac13-ec26728cb592|b03dba4f-892f-365c-bfd1-bfcfa7a98d5d|7ed6b84a-b847-3744-9d42-15c42297a0c2|d47b3510-2895-3b70-9897-342d681c769d|wellness      |162673000|General examination of patient (procedure)|129.16             |129.16          |129.16        |nan        |nan                               |
# |1e0d6b0e-1711-4a25-99f9-b1c700c9b260|2010-05-05T00:26:23Z|2010-05-05T01:11:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|b0e04623-b02c-3f8b-92ea-943fc4db60da|58b66cc1-2b86-377f-ad77-ad8164388e50|b1c428d6-4f07-31e0-90f0-68ffa6ff8c76|outpatient    |698314001|Consultation for treatment                |129.16             |129.16          |0.0           |nan        |nan                               |
# |6aa37300-d1b4-48e7-a2f8-5e0f70f48f38|2011-04-30T00:26:23Z|2011-04-30T01:03:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|b0e04623-b02c-3f8b-92ea-943fc4db60da|58b66cc1-2b86-377f-ad77-ad8164388e50|b1c428d6-4f07-31e0-90f0-68ffa6ff8c76|outpatient    |698314001|Consultation for treatment                |129.16             |129.16          |0.0           |nan        |nan                               |
# |9d35ec9f-352a-4629-92ef-38eae38437e7|2011-08-10T00:26:23Z|2011-08-10T00:41:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|b0e04623-b02c-3f8b-92ea-943fc4db60da|58b66cc1-2b86-377f-ad77-ad8164388e50|4d71f845-a6a9-3c39-b242-14d25ef86a8d|ambulatory    |185345009|Encounter for symptom                     |129.16             |129.16          |64.16         |444814009.0|Viral sinusitis (disorder)        |
# |ae7555a9-eaff-4c09-98a7-21bc6ed1b1fd|2011-11-17T00:26:23Z|2011-11-17T00:41:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|b0e04623-b02c-3f8b-92ea-943fc4db60da|58b66cc1-2b86-377f-ad77-ad8164388e50|4d71f845-a6a9-3c39-b242-14d25ef86a8d|ambulatory    |185345009|Encounter for symptom                     |129.16             |129.16          |64.16         |195662009.0|Acute viral pharyngitis (disorder)|
# |7253a9f9-6f6d-429a-926a-7b1d424eae3f|2012-04-24T00:26:23Z|2012-04-24T00:41:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|b0e04623-b02c-3f8b-92ea-943fc4db60da|58b66cc1-2b86-377f-ad77-ad8164388e50|b1c428d6-4f07-31e0-90f0-68ffa6ff8c76|outpatient    |698314001|Consultation for treatment                |129.16             |129.16          |0.0           |nan        |nan                               |
# +------------------------------------+--------------------+--------------------+------------------------------------+------------------------------------+------------------------------------+------------------------------------+--------------+---------+------------------------------------------+-------------------+----------------+--------------+-----------+----------------------------------+
# only showing top 10 rows

# %%
# Converting Pandas Dataframe into Spark Dataframe
observation_df = observation_df.astype(str) # Converting pandas df to string first
observation_df.dtypes
observation_sdf = spark.createDataFrame(observation_df)
observation_sdf.show(10, False) # False allows us to show entire content of the columns
# Out:
# +--------------------+------------------------------------+------------------------------------+-------+-------------------------------------------------------------+-----+-------+-------+
# |DATE                |PATIENT                             |ENCOUNTER                           |CODE   |DESCRIPTION                                                  |VALUE|UNITS  |TYPE   |
# +--------------------+------------------------------------+------------------------------------+-------+-------------------------------------------------------------+-----+-------+-------+
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|8302-2 |Body Height                                                  |193.3|cm     |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|72514-3|Pain severity - 0-10 verbal numeric rating [Score] - Reported|2.0  |{score}|numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|29463-7|Body Weight                                                  |87.8 |kg     |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|39156-5|Body Mass Index                                              |23.5 |kg/m2  |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|8462-4 |Diastolic Blood Pressure                                     |82.0 |mm[Hg] |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|8480-6 |Systolic Blood Pressure                                      |119.0|mm[Hg] |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|8867-4 |Heart rate                                                   |77.0 |/min   |numeric|
# |2012-01-23T17:45:28Z|034e9e3b-2def-4559-bb2a-7850888ae060|e88bc3a9-007c-405e-aabc-792a38f4aa2b|9279-1 |Respiratory rate                                             |14.0 |/min   |numeric|
# |2011-11-17T00:26:23Z|8d4c4326-e9de-4f45-9a4c-f8c36bff89ae|ae7555a9-eaff-4c09-98a7-21bc6ed1b1fd|8310-5 |Body temperature                                             |37.1 |Cel    |numeric|
# |2010-07-27T12:58:08Z|10339b10-3cd1-4ac3-ac13-ec26728cb592|dae2b7cb-1316-4b78-954f-fa610a6c6d0e|8302-2 |Body Height                                                  |165.0|cm     |numeric|
# +--------------------+------------------------------------+------------------------------------+-------+-------------------------------------------------------------+-----+-------+-------+
# only showing top 10 rows

# %% [markdown]
# ## Inner Join Query PySpark

# %%
fhir_sdf = observation_sdf.join(encounter_sdf,(observation_sdf.ENCOUNTER == encounter_sdf.Id) & (observation_sdf.PATIENT == encounter_sdf.PATIENT), "inner").select(observation_sdf.PATIENT, 'VALUE', 'UNITS', observation_sdf.DESCRIPTION,'ENCOUNTERCLASS', encounter_sdf.DESCRIPTION.alias("INFORMATION")).collect()
fhir_sdf
# Out:
# [Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='62.4', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='1.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='7.0', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='80.4', UNITS='%', DESCRIPTION='Weight-for-length Per age and sex', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='41.1', UNITS='cm', DESCRIPTION='Head Occipital-frontal circumference', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='83.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='108.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='93.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='13.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='01207ecd-9dff-4754-8887-4652eda231e2', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='158.8', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='76.1', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='30.2', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='80.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='103.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='72.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='16.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='66.7', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='16.2', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='1.4', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='10.1', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='140.5', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='4.1', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='106.1', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='26.6', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='160.7', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='117.6', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='57.6', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='79.6', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='5.9', UNITS='%', DESCRIPTION='Hemoglobin A1c/Hemoglobin.total in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='158.8', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='76.1', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='30.2', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='77.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='117.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='78.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='14.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='72.1', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='9.2', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='1.0', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='8.9', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='138.3', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='5.0', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='104.2', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='28.3', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='2c634692-05d8-4122-9f46-dd9402e2cfc6', VALUE='6.3', UNITS='%', DESCRIPTION='Hemoglobin A1c/Hemoglobin.total in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='187.9', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='0.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='98.7', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='28.0', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='79.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='114.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='78.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='14.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='44c8b4c8-4457-4ba0-94b6-285ef327a249', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='167.2', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='77.5', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='27.7', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='81.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='116.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='60.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='12.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='4.2', UNITS='10*3/uL', DESCRIPTION='Leukocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='5.5', UNITS='10*6/uL', DESCRIPTION='Erythrocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='16.7', UNITS='g/dL', DESCRIPTION='Hemoglobin [Mass/volume] in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='48.3', UNITS='%', DESCRIPTION='Hematocrit [Volume Fraction] of Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='83.8', UNITS='fL', DESCRIPTION='MCV [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='32.2', UNITS='pg', DESCRIPTION='MCH [Entitic mass] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='33.1', UNITS='g/dL', DESCRIPTION='MCHC [Mass/volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='41.1', UNITS='fL', DESCRIPTION='Erythrocyte distribution width [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='441.1', UNITS='10*3/uL', DESCRIPTION='Platelets [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='288.5', UNITS='fL', DESCRIPTION='Platelet distribution width [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='11.0', UNITS='fL', DESCRIPTION='Platelet mean volume [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='799d0738-d5cd-4161-bdb8-e3c49e21ec66', VALUE='Former smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='161.7', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='0.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='71.2', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='27.2', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='83.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='116.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='62.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='14.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='71.4', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='13.5', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='0.7', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='9.8', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='138.4', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='4.4', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='103.3', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='28.2', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='160.7', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='122.9', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='74.5', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='61.6', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='Former smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='89752052-a38b-45f0-a590-3950bbb67bec', VALUE='6.1', UNITS='%', DESCRIPTION='Hemoglobin A1c/Hemoglobin.total in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='69.3', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='1.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='8.6', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='71.6', UNITS='%', DESCRIPTION='Weight-for-length Per age and sex', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='43.8', UNITS='cm', DESCRIPTION='Head Occipital-frontal circumference', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='82.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='120.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='66.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='13.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='e19ef77e-c29c-4fe6-9790-23d53ef5158f', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='179.0', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='4.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='96.8', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='30.2', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='83.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='102.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='90.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='12.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='8.6', UNITS='10*3/uL', DESCRIPTION='Leukocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='5.1', UNITS='10*6/uL', DESCRIPTION='Erythrocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='13.7', UNITS='g/dL', DESCRIPTION='Hemoglobin [Mass/volume] in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='41.2', UNITS='%', DESCRIPTION='Hematocrit [Volume Fraction] of Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='80.9', UNITS='fL', DESCRIPTION='MCV [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='28.9', UNITS='pg', DESCRIPTION='MCH [Entitic mass] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='35.7', UNITS='g/dL', DESCRIPTION='MCHC [Mass/volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='42.8', UNITS='fL', DESCRIPTION='Erythrocyte distribution width [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='328.3', UNITS='10*3/uL', DESCRIPTION='Platelets [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='436.6', UNITS='fL', DESCRIPTION='Platelet distribution width [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='10.6', UNITS='fL', DESCRIPTION='Platelet mean volume [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bb089c44-7126-4acd-a2fa-5e10dfa77516', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='122.6', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='4.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='29.7', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='19.8', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='88.7', UNITS='%', DESCRIPTION='Body mass index (BMI) [Percentile] Per age and gender', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='75.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='111.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='82.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='13.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='f369d5b2-a190-4ca5-bd2b-c10016b1db1d', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='181.2', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='4.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='82.6', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='25.2', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='76.8', UNITS='%', DESCRIPTION='Body mass index (BMI) [Percentile] Per age and gender', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='81.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='117.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='81.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='13.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='0e003777-2825-44c6-b090-c6df626f7f4a', VALUE='Former smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='160.1', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='1.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='72.0', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='28.1', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='75.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='109.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='83.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='15.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1786920f-c6fd-4fa7-a0dc-70a5ccc1fc79', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='172.9', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='89.8', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='30.1', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='75.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='110.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='99.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='13.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='89.3', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='11.2', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='1.0', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='8.6', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='138.2', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='4.0', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='107.2', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='24.5', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='166.0', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='122.2', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='63.9', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='77.7', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='066c0f3d-90bb-4082-99ec-f307c4759f50', VALUE='6.2', UNITS='%', DESCRIPTION='Hemoglobin A1c/Hemoglobin.total in Blood', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='88.4', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='11.9', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='2.5', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='8.7', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='136.8', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='3.9', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='104.5', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='26.4', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='71.8', UNITS='mL/min', DESCRIPTION='Glomerular filtration rate/1.73 sq M.predicted', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='79.4', UNITS='g/dL', DESCRIPTION='Protein [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='5.4', UNITS='g/dL', DESCRIPTION='Albumin [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='2.1', UNITS='g/L', DESCRIPTION='Globulin [Mass/volume] in Serum by calculation', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='0.4', UNITS='mg/dL', DESCRIPTION='Bilirubin.total [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='55.5', UNITS='U/L', DESCRIPTION='Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='51.8', UNITS='U/L', DESCRIPTION='Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='24.8', UNITS='U/L', DESCRIPTION='Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='194.7', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='105.6', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='95.2', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='78.2', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='77.9', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='12.7', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='3.0', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='9.8', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='138.0', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='3.9', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='101.7', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='27.6', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='89.5', UNITS='mL/min', DESCRIPTION='Glomerular filtration rate/1.73 sq M.predicted', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='72.5', UNITS='g/dL', DESCRIPTION='Protein [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='4.8', UNITS='g/dL', DESCRIPTION='Albumin [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='3.3', UNITS='g/L', DESCRIPTION='Globulin [Mass/volume] in Serum by calculation', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='0.9', UNITS='mg/dL', DESCRIPTION='Bilirubin.total [Mass/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='54.0', UNITS='U/L', DESCRIPTION='Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='28.9', UNITS='U/L', DESCRIPTION='Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='11.1', UNITS='U/L', DESCRIPTION='Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='185.3', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='175.4', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='124.9', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='e4945ad4-5f21-460f-a420-98a32ef61d3d', VALUE='60.6', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='ambulatory', INFORMATION='Follow-up encounter'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='186.0', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='0.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='98.5', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='28.5', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='100.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='174.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='64.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='16.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b0c26ab6-b914-4bb7-8cf0-e390b6411df0', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='bc95d200-52fc-49cd-b128-8f4150cb4714', VALUE='62.9', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bc95d200-52fc-49cd-b128-8f4150cb4714', VALUE='1.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bc95d200-52fc-49cd-b128-8f4150cb4714', VALUE='6.4', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bc95d200-52fc-49cd-b128-8f4150cb4714', VALUE='22.7', UNITS='%', DESCRIPTION='Weight-for-length Per age and sex', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
# ...
#  Row(PATIENT='ca24f616-30cc-4351-aca9-1b49297de076', VALUE='10.5', UNITS='fL', DESCRIPTION='Platelet mean volume [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ca24f616-30cc-4351-aca9-1b49297de076', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='167.7', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='2.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='77.7', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='27.6', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='72.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='107.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='94.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='16.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='115.1', UNITS='mg/dL', DESCRIPTION='Glucose', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='8.6', UNITS='mg/dL', DESCRIPTION='Urea Nitrogen', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='1.7', UNITS='mg/dL', DESCRIPTION='Creatinine', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='8.8', UNITS='mg/dL', DESCRIPTION='Calcium', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='144.0', UNITS='mmol/L', DESCRIPTION='Sodium', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='4.3', UNITS='mmol/L', DESCRIPTION='Potassium', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='104.2', UNITS='mmol/L', DESCRIPTION='Chloride', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='21.1', UNITS='mmol/L', DESCRIPTION='Carbon Dioxide', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='219.0', UNITS='mg/dL', DESCRIPTION='Total Cholesterol', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='178.5', UNITS='mg/dL', DESCRIPTION='Triglycerides', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='134.0', UNITS='mg/dL', DESCRIPTION='Low Density Lipoprotein Cholesterol', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='49.3', UNITS='mg/dL', DESCRIPTION='High Density Lipoprotein Cholesterol', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='27.0', UNITS='mg/g', DESCRIPTION='Microalbumin Creatinine Ratio', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='52.3', UNITS='mL/min/{1.73_m2}', DESCRIPTION='Estimated Glomerular Filtration Rate', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='b656a85d-637d-458a-abd8-17219816280f', VALUE='3.9', UNITS='%', DESCRIPTION='Hemoglobin A1c/Hemoglobin.total in Blood', ENCOUNTERCLASS='outpatient', INFORMATION='Encounter for check up (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='160.1', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='2.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='42.7', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='16.7', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='2.2', UNITS='%', DESCRIPTION='Body mass index (BMI) [Percentile] Per age and gender', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='81.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='131.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='85.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='16.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1aa71b23-790e-4d22-92da-c689682c8993', VALUE='Former smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='162.5', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='0.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='75.1', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='28.4', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='85.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='133.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='79.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='14.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='ba2c1e9f-16e0-427b-97db-dc639daeaaee', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='General examination of patient (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='149.7', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='33.8', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='15.1', UNITS='kg/m2', DESCRIPTION='Body Mass Index', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='10.6', UNITS='%', DESCRIPTION='Body mass index (BMI) [Percentile] Per age and gender', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='75.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='135.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='71.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='14.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='8.4', UNITS='10*3/uL', DESCRIPTION='Leukocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='4.6', UNITS='10*6/uL', DESCRIPTION='Erythrocytes [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='13.1', UNITS='g/dL', DESCRIPTION='Hemoglobin [Mass/volume] in Blood', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='49.4', UNITS='%', DESCRIPTION='Hematocrit [Volume Fraction] of Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='81.3', UNITS='fL', DESCRIPTION='MCV [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='30.4', UNITS='pg', DESCRIPTION='MCH [Entitic mass] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='33.2', UNITS='g/dL', DESCRIPTION='MCHC [Mass/volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='45.0', UNITS='fL', DESCRIPTION='Erythrocyte distribution width [Entitic volume] by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='208.0', UNITS='10*3/uL', DESCRIPTION='Platelets [#/volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='179.0', UNITS='fL', DESCRIPTION='Platelet distribution width [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='11.3', UNITS='fL', DESCRIPTION='Platelet mean volume [Entitic volume] in Blood by Automated count', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='1e040769-9101-4228-9b0b-26263faf7297', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='71.5', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='3.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='9.2', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='59.1', UNITS='%', DESCRIPTION='Weight-for-length Per age and sex', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='45.9', UNITS='cm', DESCRIPTION='Head Occipital-frontal circumference', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='83.0', UNITS='mm[Hg]', DESCRIPTION='Diastolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='108.0', UNITS='mm[Hg]', DESCRIPTION='Systolic Blood Pressure', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='80.0', UNITS='/min', DESCRIPTION='Heart rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='15.0', UNITS='/min', DESCRIPTION='Respiratory rate', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='Never smoker', UNITS='nan', DESCRIPTION='Tobacco smoking status NHIS', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='76.6', UNITS='cm', DESCRIPTION='Body Height', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='2.0', UNITS='{score}', DESCRIPTION='Pain severity - 0-10 verbal numeric rating [Score] - Reported', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  Row(PATIENT='bab51ea9-2945-4f8a-8015-e430f80a908e', VALUE='10.9', UNITS='kg', DESCRIPTION='Body Weight', ENCOUNTERCLASS='wellness', INFORMATION='Well child visit (procedure)'),
#  ...]

# %%
# Columns in df
fhir_sdf = spark.createDataFrame(fhir_sdf)

# %%
# Schema: Datatypes associated with columns
fhir_sdf
# Out:
# DataFrame[PATIENT: string, VALUE: string, UNITS: string, DESCRIPTION: string, ENCOUNTERCLASS: string, INFORMATION: string]

# %%
# Total number of rows
fhir_sdf.select('ENCOUNTERCLASS').distinct().count()
# Out:
# 5

# %% [markdown]
# ## Categorical columns Transformation

# %%
from pyspark.ml.feature import StringIndexer

# Create an indexer
indexer = StringIndexer(inputCol='UNITS', outputCol='unit_id')

# Indexer identifies categories in the data
indexer_model = indexer.fit(fhir_sdf)

# Indexer creates a new column with numeric index values
fhir_indexed = indexer_model.transform(fhir_sdf)
fhir_indexed = StringIndexer(inputCol='VALUE', outputCol='value_id').fit(fhir_indexed).transform(fhir_indexed)
fhir_indexed = StringIndexer(inputCol='PATIENT', outputCol='patient_id').fit(fhir_indexed).transform(fhir_indexed)
fhir_indexed = StringIndexer(inputCol='INFORMATION', outputCol='info_id').fit(fhir_indexed).transform(fhir_indexed)
fhir_indexed = StringIndexer(inputCol='ENCOUNTERCLASS', outputCol='label').fit(fhir_indexed).transform(fhir_indexed)
fhir_indexed = StringIndexer(inputCol='DESCRIPTION', outputCol='description_id').fit(fhir_indexed).transform(fhir_indexed)

# %%
fhir_indexed
# Out:
# DataFrame[PATIENT: string, VALUE: string, UNITS: string, DESCRIPTION: string, ENCOUNTERCLASS: string, INFORMATION: string, unit_id: double, value_id: double, patient_id: double, info_id: double, label: double, description_id: double]

# %% [markdown]
# ## Assembling columns

# %%
from pyspark.ml.feature import VectorAssembler

# Create an assembler object
assembler = VectorAssembler(inputCols=[
    'unit_id', 
    'value_id',
    'patient_id',
    'description_id'
], outputCol='features_unnormalized')

# Consolidate predictor columns
fhir_assembled = assembler.transform(fhir_indexed)

# Check the resulting column
fhir_assembled.select('features_unnormalized').show(5, truncate=False)
# Out:
# +-----------------------+
# |features_unnormalized  |
# +-----------------------+
# |[6.0,1274.0,1042.0,3.0]|
# |[4.0,1.0,1042.0,0.0]   |
# |[5.0,176.0,1042.0,4.0] |
# |[8.0,335.0,1042.0,46.0]|
# |[6.0,825.0,1042.0,45.0]|
# +-----------------------+
# only showing top 5 rows

# %% [markdown]
# ## Normalization

# %%
from pyspark.ml.feature import Normalizer
normalizer = Normalizer().setInputCol("features_unnormalized").setOutputCol("features").setP(1.0)
fhir_normalized = normalizer.transform(fhir_assembled)
fhir_normalized.select('features').show(5, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------+
# |features                                                                           |
# +-----------------------------------------------------------------------------------+
# |[0.0025806451612903226,0.5479569892473118,0.4481720430107527,0.0012903225806451613]|
# |[0.0038204393505253103,9.551098376313276E-4,0.9952244508118434,0.0]                |
# |[0.004074979625101874,0.14343928280358598,0.8492257538712307,0.0032599837000814994]|
# |[0.005590496156533892,0.23410202655485673,0.7281621243885394,0.03214535290006988]  |
# |[0.0031282586027111575,0.4301355578727841,0.543274244004171,0.02346193952033368]   |
# +-----------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# # Step 3: Decision Tree

# %%
# Split into training and test sets in a 80:20 ratio
fhir_train, fhir_test = fhir_normalized.randomSplit([0.8, 0.2], seed=17)

# Check that training set has around 80% of records
training_ratio = fhir_train.count() / fhir_normalized.count()
print(training_ratio)
# Out:
# 0.7988482701775491

# %%
from pyspark.ml.classification import DecisionTreeClassifier

# Create a classifier object and fit to the training data
tree = DecisionTreeClassifier()
tree_model = tree.fit(fhir_train)

# Create predictions for the testing data and take a look at the predictions
prediction = tree_model.transform(fhir_test)
prediction.select('label', 'prediction', 'probability').show(5, False)
# Out:
# +-----+----------+------------------------------------------------------------------------------------------------------+
# |label|prediction|probability                                                                                           |
# +-----+----------+------------------------------------------------------------------------------------------------------+
# |0.0  |0.0       |[0.858298201841177,0.08080529983653102,0.04886001892798761,0.006624795663770111,0.0054116837305342854]|
# |0.0  |0.0       |[0.858298201841177,0.08080529983653102,0.04886001892798761,0.006624795663770111,0.0054116837305342854]|
# |0.0  |0.0       |[0.858298201841177,0.08080529983653102,0.04886001892798761,0.006624795663770111,0.0054116837305342854]|
# |0.0  |0.0       |[0.858298201841177,0.08080529983653102,0.04886001892798761,0.006624795663770111,0.0054116837305342854]|
# |0.0  |0.0       |[0.858298201841177,0.08080529983653102,0.04886001892798761,0.006624795663770111,0.0054116837305342854]|
# +-----+----------+------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# # Step 4: Evaluation

# %%
# Convert data using map matching with multiclass metrics evaluation
prediction_rdd = prediction.select('label', 'prediction')
prediction_map = prediction_rdd.rdd.map(lambda pred: (pred.label, pred.prediction)).collect()

# %%
# Creating Spark Context
from pyspark import SparkContext
sc = SparkContext.getOrCreate()

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
prediction.groupBy('label', 'prediction').count().show()

predictionAndLabels = sc.parallelize(prediction_map)
metrics = MulticlassMetrics(predictionAndLabels)
metrics.confusionMatrix().toArray()

# Evaluation 
print("Acuracy: ", metrics.accuracy)
print("Precision: ", metrics.precision(1.0))
print("Recall: ", metrics.recall(2.0))
print("fMeasure: ", metrics.fMeasure(0.0, 2.0))
# Out:
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  2.0|       0.0| 1947|
# |  1.0|       1.0| 5226|
# |  3.0|       2.0| 1183|
# |  4.0|       2.0|   58|
# |  0.0|       1.0|  860|
# |  1.0|       0.0| 3699|
# |  2.0|       2.0| 5203|
# |  3.0|       1.0|  395|
# |  2.0|       3.0|  248|
# |  2.0|       1.0|  639|
# |  1.0|       2.0| 2502|
# |  0.0|       0.0|27522|
# |  1.0|       3.0|  557|
# |  0.0|       2.0| 2069|
# |  4.0|       0.0|  195|
# |  3.0|       3.0| 1521|
# |  0.0|       3.0|   75|
# |  3.0|       0.0|  216|
# |  4.0|       1.0|   61|
# |  4.0|       3.0|    1|
# +-----+----------+-----+
# /content/spark-3.2.1-bin-hadoop2.7/python/pyspark/sql/context.py:127: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning
# Acuracy:  0.728574856488916
# Precision:  0.43608144192256343
# Recall:  0.47235587834770765
# fMeasure:  0.8347993836522246

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator

# Find weighted precision
multi_evaluator = MulticlassClassificationEvaluator()
weighted_precision = multi_evaluator.evaluate(prediction, {multi_evaluator.metricName: "accuracy"})
print(weighted_precision)
# Out:
# 0.728574856488916
